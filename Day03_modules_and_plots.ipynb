# %% [markdown]
# <a href="https://colab.research.google.com/github/ckraju/fmml-jan-/blob/main/Day03_modules_and_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vehicle_bucket = ['TN01', 'KA03', 'TS01', 'KA04', 'AP04', 'KL01', 'TS03']

# %%
KA_vehicle = []

# %%
for each_item in vehicle_bucket:
  if 'KA' in each_item:
    KA_vehicle.append(each_item)

# %%
KA_vehicle
# Out:
# ['KA03', 'KA04']

# %%
# list comprehension
KA_list = [each_item for each_item in vehicle_bucket if 'KA' in each_item]

# %%
KA_list
# Out:
# ['KA03', 'KA04']

# %%
import random

# %%
random.random()
# Out:
# 0.9707293182638428

# %%
my_random_list = [random.randint(18, 24) for i in range(20)]

# %%
my_random_list
# Out:
# [22,
#  21,
#  23,
#  24,
#  21,
#  19,
#  18,
#  23,
#  20,
#  21,
#  22,
#  18,
#  21,
#  20,
#  21,
#  18,
#  24,
#  21,
#  19,
#  22]

# %%
my_random_list
# Out:
# [22,
#  21,
#  23,
#  24,
#  21,
#  19,
#  18,
#  23,
#  20,
#  21,
#  22,
#  18,
#  21,
#  20,
#  21,
#  18,
#  24,
#  21,
#  19,
#  22]

# %%
import matplotlib.pyplot as plt

# %%
import math

# %%
math.sqrt(6)
# Out:
# 2.449489742783178

# %%
my_sqrt_list = [math.sqrt(each_item) for each_item in my_random_list]

# %%
plt.xlabel('X')
plt.ylabel('Random(X)')
plt.plot(my_random_list, label='random function');
plt.plot(my_sqrt_list, label='square roots of random numbers');
plt.legend();
